# %%
# thanks to echemdata (https://github.com/echemdata/galvani) 
# for source code of converting mpr files to python readable file.

# %%
from galvani import BioLogic
import pandas as pd
import os

# %%
# search mpr in current directory.
def searchmpr():
    files = []
    for file in os.listdir("."):
        if file.endswith(".mpr"): # take all the files that ends with .mpr format and append the file into the list
            files.append(file)
    return files # return list of files with .mpr format

# %%
# convert mpr to pandas dataframe
def convertToPandasDF(mprfiles):
    # if only 1 file
    if isinstance(mprfiles, str):
        mpr_file = BioLogic.MPRfile(mprfiles)
        df = pd.DataFrame(mpr_file.data)
        return df
    
    # multiple files in a list
    mpr_files = []
    for file in mprfiles:
        mpr_files.append(BioLogic.MPRfile(file))
    
    dataframes = []
    for convertedMPR in mpr_files:
        dataframes.append(pd.DataFrame(convertedMPR.data))
    return dataframes

# %%
def mpr_pandas():
    files = searchmpr()
    dfs = convertToPandasDF(files)
    return dfs

# %% [markdown]
# ## MPR to Pandas

# %%
# TO USE: call function mpr_pandas and assign to variable

dfs = mpr_pandas()

# %%
# to see files: assign the function searchmpr() to a variable and print it

files = searchmpr()
files
# Out:
# ['20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_01_GEIS_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_02_GCPL6_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_03_GEIS_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_04_GCPL6_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_05_GEIS_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_06_GCPL6_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_07_GEIS_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_08_GCPL6_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_09_GEIS_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_10_GCPL6_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_11_GEIS_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_12_GCPL6_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_13_GEIS_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_14_GCPL6_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_15_GEIS_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_16_GCPL6_C08.mpr',
#  '20220309_(Form02C)EIS_charging_10bis16V_step_01V+(1C+EIS)50cycle_17_GEIS_C08.mpr']

# %%
# to access dataframe, type in dfs[index] with the chosen index
# example:

# dfs[1]

# %%
dfs[15]
# Out:
#        flags  Ns         time/s       dQ/mA.h  (Q-Qo)/mA.h  control/V/mA  \
# 0         23   0   51497.493415  0.000000e+00     0.000000      0.000000
# 1         23   0   51498.493415  0.000000e+00     0.000000      0.000000
# 2         23   0   51499.493415  0.000000e+00     0.000000      0.000000
# 3         23   0   51500.493415  0.000000e+00     0.000000      0.000000
# 4         23   0   51501.493415  0.000000e+00     0.000000      0.000000
# ...      ...  ..            ...           ...          ...           ...
# 46496      2   2  996522.065678 -3.205759e-04     0.002772     -0.000049
# 46497      2   2  996522.065878 -5.564520e-10     0.002772     -0.000049
# 46498     23   2  996522.114278  0.000000e+00     0.002772     -0.000049
# 46499     23   2  996582.016405  0.000000e+00     0.002772      0.000000
# 46500     87   2  996582.066005  0.000000e+00     0.002772      0.000000
#
#            Ewe/V  I Range  Q charge/discharge/mA.h  half cycle      Ece/V  \
# 0      10.514146       14                 0.000000           0  13.587270
# 1      15.161330       14                 0.000000           0  13.574061
# 2      15.162132       14                 0.000000           0  13.574342
# 3      15.162454       14                 0.000000           0  13.574542
# 4      15.162774       14                 0.000000           0  13.575063
# ...          ...      ...                      ...         ...        ...
# 46496  13.575693       13                -0.142126          99  13.578511
# 46497  13.575572       13                -0.142126          99  13.578271
# 46498  10.514146       13                -0.142126          99  13.592583
# 46499  13.672843       14                -0.142126          99  13.576867
# 46500  13.672522       14                -0.142126          99  13.576587
#
#             P/W  Energy charge/W.h  Energy discharge/W.h  \
# 0      0.000000           0.000000               0.00000
# 1      0.000000           0.000000               0.00000
# 2      0.000000           0.000000               0.00000
# 3      0.000000           0.000000               0.00000
# 4      0.000000           0.000000               0.00000
# ...         ...                ...                   ...
# 46496 -0.000138           0.001967               0.00193
# 46497 -0.000136           0.001967               0.00193
# 46498  0.000000           0.001967               0.00193
# 46499  0.000000           0.001967               0.00193
# 46500  0.000000           0.001967               0.00193
#
#        Capacitance charge/µF  Capacitance discharge/µF
# 0                   0.000000                  0.000000
# 1                   0.000000                  0.000000
# 2                   0.000000                  0.000000
# 3                   0.000000                  0.000000
# 4                   0.000000                  0.000000
# ...                      ...                       ...
# 46496          170313.644125             167122.817743
# 46497          170313.644125             167129.430137
# 46498          170313.644125             167129.430137
# 46499          170313.644125             167129.430137
# 46500          170313.644125             167129.430137
#
# [46501 rows x 16 columns]
